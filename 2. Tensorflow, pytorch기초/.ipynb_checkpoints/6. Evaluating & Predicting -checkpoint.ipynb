# %% [markdown]
# # 6. Evaluating & Predicting
# - 학습한 모델 확인

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import datasets


(train_x, train_y), (test_x, test_y) = datasets.mnist.load_data()

# %%
inputs = layers.Input((28, 28, 1))
net = layers.Conv2D(32, (3,3), padding = 'SAME')(inputs)
net = layers.Activation('relu')(net)

net = layers.Conv2D(32, 3, padding = 'SAME')(net)
net = layers.Activation('relu')(net)

net = layers.MaxPooling2D(pool_size = (2, 2))(net)
net = layers.Dropout(0.25)(net)

net = layers.Conv2D(64, 3, padding = 'SAME')(net)
net = layers.Activation('relu')(net)

net = layers.Conv2D(64, 3, padding = 'SAME')(net)
net = layers.Activation('relu')(net)

net = layers.MaxPooling2D(pool_size = (2, 2))(net)
net = layers.Dropout(0.25)(net)

net =layers.Flatten()(net)
net = layers.Dense(512)(net)
net = layers.Activation('relu')(net)
net = layers.Dropout(0.5)(net)
net = layers.Dense(10)(net)
net = layers.Activation('softmax')(net)

model = tf.keras.Model(inputs = inputs, outputs = net, name = 'BASIC_CNN')


loss_func = tf.keras.losses.sparse_categorical_crossentropy
metrics = ['accuracy']
optm = tf.keras.optimizers.Adam()
model.compile(optimizer= optm, 
                  loss = loss_func, 
                  metrics = metrics) 

train_x.shape, train_y.shape, test_x.shape, test_y.shape


train_x = train_x[..., tf.newaxis]
test_x = test_x[..., tf.newaxis]

np.min(train_x), np.max(train_x)
train_x = train_x/255.
test_x = test_x/255.
np.min(train_x), np.max(test_x)

num_epochs = 1
batch_size  = 32

#hist = model.fit(train_x, train_y,
             # batch_size = batch_size, 
             #shuffle = True,  #데이터가 순서대로 들어가면 특정 숫자에 bias가 걸리게 된다. 그래서 랜덤하게 데이터를 섞어주는게 필요하다.
            # epochs = num_epochs)

##########지금까지 학습한 것들############

# %%
#hist.history #hist를 주면 학습 log가 저장된다.

# %% [markdown]
# ## Evaluating & Prediction
# - 학습한 모델 확인

# %%
model.evaluate(test_x, test_y, batch_size = batch_size)
#test set에 대해서 loss가 얼마만큼 나왔는지 loss와 accucacy 가 나온다.
# Out:
# 10000/1 [=============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...

# %% [markdown]
# ### 1) 결과 확인
# input으로 들어갈 이미지 데이터 시각화하여 확인

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
test_image = test_x[0, :, :, 0]
test_image.shape
# Out:
# (28, 28)

# %% [markdown]
# #### 1.  Test Data 시각화

# %%
#시각화
#from tensorflow.keras.utils import to_categorical
#label_onehot = to_categorical(test_y[0], num_classes = 10)

plt.title(test_y[0])
plt.imshow(test_image, 'gray')
plt.show()

# %% [markdown]
# #### 2. Test Data 준비

# %%
#이 이미지 데이터를 모델에 넣을 것
test_image.shape
test_image.reshape(1, 28, 28, 1)

# %% [markdown]
# #### 3. Test Data 모델에 넣기 - Prediction

# %%
predict = model.predict(test_image)
predict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-924c07981c09> in <module>
# ----> 1 predict = model.predict(test_image)
#       2 predict
#
# NameError: name 'model' is not defined

# %% [markdown]
# #### 4. 결과 확인

# %%
#predict중 가장 높은 값이 이 모델이 생각한 정답이다. 
np.argmax(predict)

# %% [markdown]
# ### 2) Test Batch
# 앞에서는 test_x[0]하나만 넣어 봤는데
# 이제 batch로 test dataset을 넣어보고자 한다.

# %% [markdown]
# #### 1. batch로 test data  준비

# %%
test_batch = test_x[:32]
test_batch.shape

# %% [markdown]
# #### 2. Batch Test Dataset 모델에 넣기 - Prediction

# %%
pedict = model.predict(test_batch.reshape(32, 28, 28, 1))
predict.shape

# %% [markdown]
# #### 3. 결과 확인

# %%
np.argmax(predict, -1) #32개에 대한 각자의 결과값이 나옴
